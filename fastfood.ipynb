# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('fastfood.csv')
df.head(100)
# Out:
#    restaurant                                            item  calories  \
# 0   Mcdonalds                Artisan Grilled Chicken Sandwich       380
# 1   Mcdonalds                  Single Bacon Smokehouse Burger       840
# 2   Mcdonalds                  Double Bacon Smokehouse Burger      1130
# 3   Mcdonalds       Grilled Bacon Smokehouse Chicken Sandwich       750
# 4   Mcdonalds        Crispy Bacon Smokehouse Chicken Sandwich       920
# ..        ...                                             ...       ...
# 95      Sonic                   Sonic Cheeseburger W/ Mustard       710
# 96      Sonic                   Sonic Cheeseburger W/ Ketchup       720
# 97      Sonic                Sonic Cheeseburger W/ Mayonnaise       800
# 98      Sonic  Super Sonic Bacon Double Cheeseburger (w/mayo)      1280
# 99      Sonic      Super Sonic Double Cheeseburger W/ Mustard      1120
#
#     cal_fat  total_fat  sat_fat  trans_fat  cholesterol  sodium  total_carb  \
# 0        60          7      2.0        0.0           95    1110          44
# 1       410         45     17.0        1.5          130    1580          62
# 2       600         67     27.0        3.0          220    1920          63
# 3       280         31     10.0        0.5          155    1940          62
# 4       410         45     12.0        0.5          120    1980          81
# ..      ...        ...      ...        ...          ...     ...         ...
# 95      380         43     17.0        2.0          120    1120          43
# 96      380         43     17.0        2.0          120    1190          47
# 97      480         54     18.0        2.0          130    1090          44
# 98      830         92     36.0        4.0          260    1630          44
# 99      680         76     32.0        4.0          235    1550          44
#
#     fiber  sugar  protein  vit_a  vit_c  calcium  salad
# 0     3.0     11     37.0    4.0   20.0     20.0  Other
# 1     2.0     18     46.0    6.0   20.0     20.0  Other
# 2     3.0     18     70.0   10.0   20.0     50.0  Other
# 3     2.0     18     55.0    6.0   25.0     20.0  Other
# 4     4.0     18     46.0    6.0   20.0     20.0  Other
# ..    ...    ...      ...    ...    ...      ...    ...
# 95    2.0      7     35.0   10.0    8.0     30.0  Other
# 96    2.0     10     35.0   15.0   10.0     30.0  Other
# 97    2.0      7     35.0   10.0    8.0     30.0  Other
# 98    2.0      7     67.0   15.0    6.0     40.0  Other
# 99    2.0      8     63.0   15.0    8.0     40.0  Other
#
# [100 rows x 17 columns]

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='restaurant', data=df, palette='coolwarm', edgecolor='black')
plt.title('Number of Menu Items per Restaurant')
plt.xlabel('Restaurant')
plt.tight_layout()
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14736\3914367585.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='restaurant', data=df, palette='coolwarm', edgecolor='black')

# %%
sns.histplot(df['calories'], bins=5, kde=True, color='lime', edgecolor='black')
plt.title("Distribution of Calories Across Fast Food Items")
plt.xlabel("Calories")
plt.ylabel("Frequency")
plt.show()

# %%
df = pd.read_csv("fastfood.csv")

sns.pairplot(df[['calories', 'total_fat', 'protein', 'sodium']], diag_kind='hist')
plt.suptitle("Pairplot: Comparing Nutrients in McDonald's Menu", y=1.02)
plt.show()

# %%
cal_by_type = df.groupby('salad')['calories'].mean()
plt.pie(cal_by_type, labels=cal_by_type.index, autopct='%1.1f%%', startangle=90)
plt.title("Average Calories by Salad Type")
plt.show()

# %%
c = df.sort_values('protein', ascending=False).head(10)
sns.barplot(x='item', y='protein', data=c, palette='inferno')
plt.title("Top 10 Items by Protein Content")
plt.xlabel("Item")
plt.ylabel("Protein (g)")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14736\2858040253.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='item', y='protein', data=c, palette='inferno')

# %%
df= df.corr(numeric_only=True)
plt.figure(figsize=(8,6))
sns.heatmap(df, annot=True, cmap='coolwarm', fmt=".2f")
plt.title(" First 100 McDonald's Items")
plt.show()
